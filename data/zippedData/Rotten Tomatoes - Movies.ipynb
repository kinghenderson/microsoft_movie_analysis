# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("rotten_tomatoes_movies.csv.gz")
df
df.sort_values(by=['tomatometer_rating'], inplace=True, ascending=False)
df.dropna(how='all')
# Out:
#                    rotten_tomatoes_link                         movie_title  \
# 16908   m/vikings_journey_to_new_worlds      Vikings: Journey to New Worlds
# 2021                               m/5b                                  5B
# 17322  m/who_the_and_is_jackson_pollock    Who the #$&% Is Jackson Pollock?
# 6693                m/frankenstein_2015                        Frankenstein
# 12044                         m/primary                             Primary
# ...                                 ...                                 ...
# 17093                 m/we_are_the_heat                     We Are the Heat
# 17206                   m/what_we_found                       What We Found
# 17531   m/world_the_flesh_and_the_devil  The World, the Flesh and the Devil
# 17620                      m/you_get_me                          You Get Me
# 17671                          m/z_2019                                   Z
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Movie_Titles = pd.read_csv("data/zippeddata/imdb.title.basics.csv.gz")
Movie_Titles.sort_values(by=['runtime_minutes'], inplace=True, ascending=False)

# %%
Movie_Titles.dropna(inplace=True)
Movie_Titles.drop(['primary_title'], axis=1)
Movie_Titles.drop(['tconst'], axis=1)
# Out:
#                                             primary_title  \
# 132389                                          Logistics
# 44840                                Modern Times Forever
# 123467                                               Nari
# 87264                                             Hunger!
# 88717                                          London EC1
# ...                                                   ...
# 2570    Lamentation For Little Girls Who Are In Love W...
# 117258                                           Champion
# 60809                                            November
# 72190                          Powered By Green Smoothies
# 93214              Great Valley Nature Center Documentary
#
#                                            original_title  start_year  \
# 132389                                          Logistics        2012
# 44840                                Modern Times Forever        2011
# ...

# %%
Sorted_Movies = Movie_Titles.sort_values(by='genres', ascending=False)
print(Sorted_Movies)
# Out:
#            tconst                   primary_title  \
# 94416   tt5503472               Gone Are the Days
# 39860   tt2418150                   Cowboy Spirit
# 64764   tt3708370                  Oro del Diablo
# 31735   tt2197881  Cole Younger & The Black Train
# 80812   tt4644836         Calamity Jane's Revenge
# ...           ...                             ...
# 34650   tt2281293                      I'm Flash!
# 62477   tt3594826    Monk Comes Down the Mountain
# 131588  tt8192456                        Wayunagu
# 115388  tt6844374                        Blinkers
# 7799    tt1455619                     Fist 2 Fist
#
#                         original_title  start_year  runtime_minutes   genres
# 94416                Gone Are the Days        2018             99.0  Western
# 39860                    Cowboy Spirit        2012             94.0  Western
# 64764                   Oro del Diablo        2013             91.0  Western
# ...

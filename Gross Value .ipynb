# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing movie gross revenue csv
gross_rev = pd.read_csv("data/zippeddata/bom.movie_gross.csv.gz")

# %%
# sorted by domestic gross and dropped na values 
sorted_movies_titles = gross_rev.sort_values(by='domestic_gross', ascending=False).dropna()
sorted_movies_titles
# Out:
#                              title  studio  domestic_gross foreign_gross  year
# 1872  Star Wars: The Force Awakens      BV     936700000.0       1,131.6  2015
# 3080                 Black Panther      BV     700100000.0     646900000  2018
# 3079        Avengers: Infinity War      BV     678800000.0       1,369.5  2018
# 1873                Jurassic World    Uni.     652300000.0       1,019.4  2015
# 727          Marvel's The Avengers      BV     623400000.0     895500000  2012
# ...                            ...     ...             ...           ...   ...
# 1738                       Jackpot      DR           800.0       1100000  2014
# 292               Perrier's Bounty     IFC           800.0        167000  2010
# 2920     Amityville: The Awakening  W/Dim.           700.0       7700000  2017
# 642                 Illegal (2011)      FM           700.0        289000  2011
# 1018                 Apartment 143   Magn.           400.0        426000  2012
#
# [2007 rows x 5 columns]

# %%
#importing movie budgets 
movie_budget = pd.read_csv('data/zippedData/tn.movie_budgets.csv.gz')
movie_budget
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
merged_df = sorted_movies_titles.merge(right= Movie_budget, how = 'inner', left_on = 'title', right_on = 'movie', suffixes=('_rounded','_budget')).head(50)

# %%
merged_df
# Out:
#                                         title   studio  \
# 0                               Black Panther       BV
# 1                      Avengers: Infinity War       BV
# 2                              Jurassic World     Uni.
# 3                               Incredibles 2       BV
# 4                Rogue One: A Star Wars Story       BV
# 5                                Finding Dory       BV
# 6                     Avengers: Age of Ultron       BV
# 7                       The Dark Knight Rises       WB
# 8             The Hunger Games: Catching Fire      LGF
# 9              Jurassic World: Fallen Kingdom     Uni.
# 10                                Toy Story 3       BV
# 11                               Wonder Woman       WB
# 12                                 Iron Man 3       BV
# 13                 Captain America: Civil War       BV
# 14                           The Hunger Games      LGF
# 15             Jumanji: Welcome to the Jungle     Sony
# 16                                     Frozen       BV
# 17                    The Secret Life of Pets     Uni.
# 18                            Despicable Me 2     Uni.
# 19                                   Deadpool      Fox
# 20                                 Inside Out       BV
# 21                                  Furious 7     Uni.
# 22             Transformers: Dark of the Moon     P/DW
# 23                            American Sniper       WB
# 24                                   Zootopia       BV
# 25      The Hunger Games: Mockingjay - Part 1      LGF
# 26                                    Minions     Uni.
# 27                                    Aquaman       WB
# 28                     Spider-Man: Homecoming     Sony
# 29                    Guardians of the Galaxy       BV
# 30         Batman v Superman: Dawn of Justice       WB
# 31                                         It  WB (NL)
# 32                              Suicide Squad       WB
# 33                                 Deadpool 2      Fox
# 34                             Thor: Ragnarok       BV
# 35                                 Iron Man 2     Par.
# 36                                    Skyfall     Sony
# 37          The Hobbit: An Unexpected Journey  WB (NL)
# 38                 The Twilight Saga: Eclipse     Sum.
# 39                                  Inception       WB
# 40                               Man of Steel       WB
# 41      The Hunger Games: Mockingjay - Part 2      LGF
# 42                                    Gravity       WB
# 43                                       Sing     Uni.
# 44                        Monsters University       BV
# 45                            Despicable Me 3     Uni.
# 46                     The Amazing Spider-Man     Sony
# 47        Captain America: The Winter Soldier       BV
# 48        The Hobbit: The Desolation of Smaug  WB (NL)
# 49  The Hobbit: The Battle of the Five Armies  WB (NL)
#
# 7                       The Dark Knight Rises      $275,000,000
# 8             The Hunger Games: Catching Fire      $130,000,000
# 9              Jurassic World: Fallen Kingdom      $170,000,000
# 10                                Toy Story 3      $200,000,000
# 11                               Wonder Woman      $150,000,000
# 12                                 Iron Man 3      $200,000,000
# 13                 Captain America: Civil War      $250,000,000
# 14                           The Hunger Games       $80,000,000
# 15             Jumanji: Welcome to the Jungle       $90,000,000
# 16                                     Frozen      $150,000,000
# 17                    The Secret Life of Pets       $75,000,000
# 18                            Despicable Me 2       $76,000,000
# 19                                   Deadpool       $58,000,000
# 20                                 Inside Out      $175,000,000
# 21                                  Furious 7      $190,000,000
# 22             Transformers: Dark of the Moon      $195,000,000
# 23                            American Sniper       $58,000,000
# 24                                   Zootopia      $150,000,000
# 25      The Hunger Games: Mockingjay - Part 1      $125,000,000
# 26                                    Minions       $74,000,000
# 27                                    Aquaman      $160,000,000
# 28                     Spider-Man: Homecoming      $175,000,000
# 29                    Guardians of the Galaxy      $170,000,000
# 30         Batman v Superman: Dawn of Justice      $250,000,000
# 31                                         It       $35,000,000
# 32                              Suicide Squad      $175,000,000
# 33                                 Deadpool 2      $110,000,000
# 34                             Thor: Ragnarok      $180,000,000
# 35                                 Iron Man 2      $170,000,000
# 36                                    Skyfall      $200,000,000
# 37          The Hobbit: An Unexpected Journey      $250,000,000
# 38                 The Twilight Saga: Eclipse       $68,000,000
# 39                                  Inception      $160,000,000
# 40                               Man of Steel      $225,000,000
# 41      The Hunger Games: Mockingjay - Part 2      $160,000,000
# 42                                    Gravity      $110,000,000
# 43                                       Sing       $75,000,000
# 44                        Monsters University      $200,000,000
# 45                            Despicable Me 3       $75,000,000
# 46                     The Amazing Spider-Man      $220,000,000
# 47        Captain America: The Winter Soldier      $170,000,000
# 48        The Hobbit: The Desolation of Smaug      $250,000,000
# 49  The Hobbit: The Battle of the Five Armies      $250,000,000
#
#    domestic_gross_budget worldwide_gross
# 0           $700,059,566  $1,348,258,224
# 1           $678,815,482  $2,048,134,200
# 2           $652,270,625  $1,648,854,864
# 3           $608,581,744  $1,242,520,711
# 4           $532,177,324  $1,049,102,856
# 5           $486,295,561  $1,021,215,193
# 6           $459,005,868  $1,403,013,963
# 7           $448,139,099  $1,084,439,099
# 8           $424,668,047    $864,868,047
# 9           $417,719,760  $1,305,772,799
# 10          $415,004,880  $1,068,879,522
# 11          $412,563,408    $821,133,378
# 12          $408,992,272  $1,215,392,272
# 13          $408,084,349  $1,140,069,413
# 14          $408,010,692    $677,923,379
# 15          $404,508,916    $964,496,193
# 16          $400,738,009  $1,272,469,910
# 17          $368,384,330    $886,750,534
# 18          $368,065,385    $975,216,835
# 19          $363,070,709    $801,025,593
# 20          $356,461,711    $854,235,992
# 21          $353,007,020  $1,518,722,794
# 22          $352,390,543  $1,123,790,543
# 23          $350,126,372    $547,326,372
# 24          $341,268,248  $1,019,429,616
# 25          $337,135,885    $766,575,131
# 26          $336,045,770  $1,160,336,173
# 27          $335,061,807  $1,146,894,640
# 28          $334,201,140    $880,166,350
# 29          $333,172,112    $770,867,516
# 30          $330,360,194    $867,500,281
# 31          $327,481,748    $697,457,969
# 32          $325,100,054    $746,059,887
# 33          $324,591,735    $786,680,557
# 34          $315,058,289    $846,980,024
# 35          $312,433,331    $621,156,389
# 36          $304,360,277  $1,110,526,981
# 37          $303,003,568  $1,017,003,568
# 38          $300,531,751    $706,102,828
# 39          $292,576,195    $835,524,642
# 40          $291,045,518    $667,999,518
# 41          $281,723,902    $648,986,787
# 42          $274,092,705    $693,698,673
# 43          $270,329,045    $634,454,789
# 44          $268,488,329    $743,588,329
# 45          $264,624,300  $1,034,727,750
# 46          $262,030,663    $757,890,267
# 47          $259,746,958    $714,401,889
# 48          $258,366,855    $960,366,855
# 49          $255,119,788    $945,577,621

# %%
# taking a column and equaling it to another variable seperate from the df
domestic_gross_rounded = merged_df.domestic_gross_rounded.head(8)

# %%
#taking a column and equaling it to another variable seperate from the df
production_budget = merged_df.production_budget.head(8)

# %%
#setting index equal to the movie titles from the df 
index = merged_df.title.head(8)

# %%
graph_prod = pd.DataFrame({'domestic_gross_rounded': domestic_gross_rounded,
                   'production_budget': production_budget }, index=index)
ax = graph_prod.plot.bar(rot=100)

# %%
#'a string'.replace('tr', '').replace(' ', '')

# %%
#consolidating columns from merged_df to fit in bar graph easier 
data = [merged_df["domestic_gross_rounded"], merged_df["production_budget"], merged_df["title"]]
headers = ["domestic_gross_rounded", "production_budget", "title"]
df_graph = pd.concat(data, axis=1, keys=headers)

# %%
df_graph = merged_df[["domestic_gross_rounded", "production_budget", "title"]]

# %%
df_graph.production_budget=df_graph.production_budget.str.replace('$', '').str.replace(',','').astype(int)
# Out:
# <ipython-input-309-f6eb5add7d77>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_graph.production_budget=df_graph.production_budget.str.replace('$', '').str.replace(',','').astype(int)
# C:\Users\kindl\anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
#transfering data from graph_df into a scatter plot 
#ax = df_graph.plot.scatter(x="production_budget", y="domestic_gross_rounded")
# df_graph.plot.scatter(x='production_budget',
#                 y='domestic_gross_rounded',
#                ylim=(250, 700),
#                xlim=(30, 350)

fig, ax = plt.subplots(figsize=(14,8))
# data = df_graph[['production_budget', 'domestic_gross_rounded']]
x = df_graph['production_budget']
y = df_graph['domestic_gross_rounded']
plt.scatter(x,y, c='black')

# 
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x), "r--")

plt.title('Do Budgets influence a movies pross profit')
plt.xlabel('budget / 10x8 value')
plt.ylabel('domestic gross / hundreds of millions')
plt.axvline(df_graph['production_budget'].mean(), color = 'blue', label='Median')
plt.legend()

# %%
#importing data and dropping nan values 
rotten_tomatoes = pd.read_csv('data/zippeddata/rotten_tomatoes_movies.csv.gz')
sorted_reviews = rotten_tomatoes.sort_values(by='movie_title', ascending=False).dropna()
sorted_reviews
# Out:
#                   rotten_tomatoes_link                        movie_title  \
# 16249          m/tie_me_up_tie_me_down   Átame! (Tie Me Up! Tie Me Down!)
# 17574         m/xxx_state_of_the_union            xXx: State of the Union
# 10619                    m/mother_2017                            mother!
# 8157                            m/iboy                               iBoy
# 12333                          m/rec_2                            [Rec] 2
# ...                                ...                                ...
# 191            m/1000_times_good_night             1,000 Times Good Night
# 2743             m/and_justice_for_all             ...And Justice for All
# 17562  m/x_the_man_with_the_x_ray_eyes  'X'---The Man With the X-Ray Eyes
# 2033                         m/71_2015                                '71
# 2055                        m/999_2008                              $9.99
#
#                                               movie_info  \
# 16249  Newly released from a mental institution, Rick...
# 17574  When the government finds out that a group of ...
# 10619  A young woman spends her days renovating the V...
# 8157   A teenager (Bill Milner) wakes from a coma to ...
# 12333  A doctor and a SWAT team enter a quarantined b...
# ...                                                  ...
# 191    A war-zone photojournalist's (Juliette Binoche...
# 2743   Satirical drama in which an idealistic lawyer ...
# 17562  Intent on enhancing mankind's ocular ability, ...
# 2033   A young British soldier (Jack O'Connell) must ...
# 2055   Residents of a Sydney, Australia, apartment co...
#
#                                        critics_consensus content_rating  \
# 16249  Tie Me Up! Tie Me Down! undermines its own eff...           NC17
# 17574  Even more absurd and implausible than the firs...              R
# 10619  There's no denying that mother! is the thought...              R
# 8157   iBoy's original premise and Maisie Williams' s...             NR
# 12333  It lacks the surprising jolt of the first inst...              R
# ...                                                  ...            ...
# 191    Beautifully filmed and powerfully acted, 1,000...             NR
# 2743   A volcanic Al Pacino holds court in this histr...              R
# 17562  By turns lurid and disturbing, The Man with th...              R
# 2033   Powerfully directed and acted, '71 stays true ...          PG-13
# 2055   Its storyline isn't as wondrous as its visuals...              R
#
#                                                   genres  \
# 16249  Art House & International, Comedy, Drama, Romance
# 17574                                 Action & Adventure
# 10619                  Drama, Horror, Mystery & Suspense
# 8157   Action & Adventure, Drama, Mystery & Suspense,...
# 12333  Drama, Horror, Mystery & Suspense, Special Int...
# ...                                                  ...
# 191                                                Drama
# 2743                   Comedy, Drama, Mystery & Suspense
# 17562     Cult Movies, Horror, Science Fiction & Fantasy
# 2033                           Action & Adventure, Drama
# 2055        Animation, Art House & International, Comedy
#
#                                      directors  \
# 16249                          Pedro Almodóvar
# 17574                             Lee Tamahori
# 10619                         Darren Aronofsky
# 8157                         Adam Randall (II)
# 12333  Paca Plaza, Jaume Balagueró, Paco Plaza
# ...                                        ...
# 191                                 Erik Poppe
# 2743                            Norman Jewison
# 17562                             Roger Corman
# 2033                              Yann Demange
# 2055                           Tatia Rosenthal
#
#                                                authors  \
# 16249                                  Pedro Almodóvar
# 17574         Simon Kinberg, Lee Tamahori, Rich Wilkes
# 10619                                 Darren Aronofsky
# 8157   Joe Barton (VIII), Mark Denton, Jonny Stockwood
# 12333                                        Manu Diez
# ...                                                ...
# 191                                Harald Rosenløw-Eeg
# 2743                    Barry Levinson, Valerie Curtin
# 17562                       Ray Russell, Robert Dillon
# 2033                                     Gregory Burke
# 2055                      Etgar Keret, Tatia Rosenthal
#
#                                                   actors  \
# 16249  Victoria Abril, Antonio Banderas, Loles León, ...
# 17574  Ice Cube, Samuel L. Jackson, Willem Dafoe, Sco...
# 10619  Jennifer Lawrence, Javier Bardem, Ed Harris, M...
# 8157   Bill Milner, Maisie Williams, Miranda Richards...
# 12333  Jonathan Mellor, Oscar Sanchez Zafra, Ariel Ca...
# ...                                                  ...
# 191    Juliette Binoche, Nikolaj Coster-Waldau, Laury...
# 2743   Al Pacino, Jack Warden, John Forsythe, Lee Str...
# 17562  Ray Milland, Don Rickles, Harold J. Stone, Dia...
# 2033   Jack O'Connell, Sean Harris, Jack Lowden, Char...
# 2055   Geoffrey Rush, Anthony LaPaglia, Samuel Johnso...
#
#       original_release_date  ...    production_company  tomatometer_status  \
# 16249            1990-01-22  ...               Miramax               Fresh
# 17574            2005-04-29  ...         Sony Pictures              Rotten
# 10619            2017-09-15  ...    Paramount Pictures               Fresh
# 8157             2017-01-27  ...               Netflix               Fresh
# 12333            2010-07-09  ...     Magnolia Pictures               Fresh
# ...                     ...  ...                   ...                 ...
# 191              2014-10-24  ...         Film Movement               Fresh
# 2743             1979-06-29  ...     Columbia Pictures               Fresh
# 17562            1963-09-18  ...      Orion Home Video               Fresh
# 2033             2015-02-27  ...  Roadside Attractions     Certified-Fresh
# 2055             2008-09-04  ...      Regent Releasing     Certified-Fresh
#
#       tomatometer_rating tomatometer_count  audience_status  audience_rating  \
# 16249               67.0              30.0          Upright             79.0
# 17574               17.0             138.0          Spilled             32.0
# 10619               68.0             374.0          Spilled             51.0
# 8157                69.0              13.0          Spilled             39.0
# 12333               68.0              72.0          Upright             60.0
# ...                  ...               ...              ...              ...
# 191                 71.0              55.0          Upright             65.0
# 2743                83.0              29.0          Upright             80.0
# 17562               88.0              25.0          Upright             66.0
# 2033                96.0             138.0          Upright             81.0
# 2055                73.0              55.0          Spilled             55.0
#
#       audience_count  tomatometer_top_critics_count  \
# 16249        17073.0                              4
# 17574       113323.0                             34
# 10619        24931.0                             51
# 8157           786.0                              3
# 12333        15340.0                             18
# ...              ...                            ...
# 191           1884.0                             22
# 2743         19067.0                              7
# 17562         3224.0                              5
# 2033         17420.0                             42
# 2055          5339.0                             24
#
#        tomatometer_fresh_critics_count  tomatometer_rotten_critics_count
# 16249                               20                                10
# 17574                               23                               115
# 10619                              256                               118
# 8157                                 9                                 4
# 12333                               49                                23
# ...                                ...                               ...
# 191                                 39                                16
# 2743                                24                                 5
# 17562                               22                                 3
# 2033                               132                                 6
# 2055                                40                                15
#
# [8077 rows x 22 columns]

# %%
tomato_board = sorted_reviews[['tomatometer_rating', 'tomatometer_status', 'movie_title']]

# %%
#merged_df = sorted_movies_titles.merge(right= Movie_budget, how = 'inner', left_on = 'title', right_on = 'movie', suffixes=('_rounded','_budget')).head(50)
ratings_production_df = df_graph.merge(right=tomato_board, how='inner', left_on = 'title', right_on = 'movie_title').head(50)

# %%
ratings_production_df
# Out:
#     domestic_gross_rounded  production_budget  \
# 0              700100000.0          200000000
# 1              678800000.0          300000000
# 2              652300000.0          215000000
# 3              608600000.0          200000000
# 4              532200000.0          200000000
# 5              486300000.0          200000000
# 6              459000000.0          330600000
# 7              448100000.0          275000000
# 8              424700000.0          130000000
# 9              417700000.0          170000000
# 10             415000000.0          200000000
# 11             412600000.0          150000000
# 12             409000000.0          200000000
# 13             408100000.0          250000000
# 14             408000000.0           80000000
# 15             404500000.0           90000000
# 16             400700000.0          150000000
# 17             400700000.0          150000000
# 18             368400000.0           75000000
# 19             368100000.0           76000000
# 20             356500000.0          175000000
# 21             353000000.0          190000000
# 22             352400000.0          195000000
# 23             350100000.0           58000000
# 24             341300000.0          150000000
# 25             337100000.0          125000000
# 26             336000000.0           74000000
# 27             334200000.0          175000000
# 28             333200000.0          170000000
# 29             330400000.0          250000000
# 30             327500000.0           35000000
# 31             325100000.0          175000000
# 32             318500000.0          110000000
# 33             315100000.0          180000000
# 34             304400000.0          200000000
# 35             303000000.0          250000000
# 36             300500000.0           68000000
# 37             292600000.0          160000000
# 23    Certified-Fresh                            American Sniper
# 24    Certified-Fresh                                   Zootopia
# 25              Fresh      The Hunger Games: Mockingjay - Part 1
# 26             Rotten                                    Minions
# 27    Certified-Fresh                     Spider-Man: Homecoming
# 28    Certified-Fresh                    Guardians of the Galaxy
# 29             Rotten         Batman v Superman: Dawn of Justice
# 30    Certified-Fresh                                         It
# 31             Rotten                              Suicide Squad
# 32    Certified-Fresh                                 Deadpool 2
# 33    Certified-Fresh                             Thor: Ragnarok
# 34    Certified-Fresh                                    Skyfall
# 35              Fresh          The Hobbit: An Unexpected Journey
# 36             Rotten                 The Twilight Saga: Eclipse
# 37    Certified-Fresh                                  Inception
# 38             Rotten                               Man of Steel
# 39              Fresh      The Hunger Games: Mockingjay - Part 2
# 40    Certified-Fresh                                    Gravity
# 41              Fresh                                       Sing
# 42    Certified-Fresh                        Monsters University
# 43             Rotten                            Despicable Me 3
# 44    Certified-Fresh                     The Amazing Spider-Man
# 45    Certified-Fresh        Captain America: The Winter Soldier
# 46    Certified-Fresh        The Hobbit: The Desolation of Smaug
# 47             Rotten  The Hobbit: The Battle of the Five Armies

# %%
fig, ax = plt.subplots(figsize=(14,8))
data = ratings_production_df[['production_budget', 'tomatometer_rating']]
x = data[['production_budget']]/1000000
y = data['tomatometer_rating']
ax.scatter(x,y, c='black')

plt.xlim(0,400)
plt.ylim(0,100)

# z = np.polyfit(x, y, 1)
# p = np.poly1d(z)
# plt.plot(x,p(x), "r--")

# z = np.polyfit(data['production_budget'], y, 1)
# p = np.poly1d(z)

plt.plot(data['production_budget'],p(x), "r--")

ax.set_title("Budgets and Ratings") 
ax.set_ylabel("Rotten Tomatos %") 
ax.set_xlabel("Budgets - hundred millions") 

plt.tight_layout()
plt.show()

# %%
merged_df.production_budget=merged_df.production_budget.str.replace('$', '').str.replace(',','').astype(int)
# Out:
# <ipython-input-387-836370df9bca>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   merged_df.production_budget=merged_df.production_budget.str.replace('$', '').str.replace(',','').astype(int)

# %%
movie_studio= merged_df[["studio", "production_budget", "title"]]
movie_studio.sort_values(by='production_budget', ascending=False).dropna().head(50)
# Out:
#      studio  production_budget                                      title
# 6        BV          330600000                    Avengers: Age of Ultron
# 1        BV          300000000                     Avengers: Infinity War
# 7        WB          275000000                      The Dark Knight Rises
# 49  WB (NL)          250000000  The Hobbit: The Battle of the Five Armies
# 13       BV          250000000                 Captain America: Civil War
# 48  WB (NL)          250000000        The Hobbit: The Desolation of Smaug
# 37  WB (NL)          250000000          The Hobbit: An Unexpected Journey
# 30       WB          250000000         Batman v Superman: Dawn of Justice
# 40       WB          225000000                               Man of Steel
# 46     Sony          220000000                     The Amazing Spider-Man
# 2      Uni.          215000000                             Jurassic World
# 44       BV          200000000                        Monsters University
# 36     Sony          200000000                                    Skyfall
# 0        BV          200000000                              Black Panther
# 12       BV          200000000                                 Iron Man 3
# 5        BV          200000000                               Finding Dory
# 3        BV          200000000                              Incredibles 2
# 4        BV          200000000               Rogue One: A Star Wars Story
# 10       BV          200000000                                Toy Story 3
# 22     P/DW          195000000             Transformers: Dark of the Moon
# 21     Uni.          190000000                                  Furious 7
# 34       BV          180000000                             Thor: Ragnarok
# 28     Sony          175000000                     Spider-Man: Homecoming
# 32       WB          175000000                              Suicide Squad
# 20       BV          175000000                                 Inside Out
# 47       BV          170000000        Captain America: The Winter Soldier
# 29       BV          170000000                    Guardians of the Galaxy
# 9      Uni.          170000000             Jurassic World: Fallen Kingdom
# 35     Par.          170000000                                 Iron Man 2
# 41      LGF          160000000      The Hunger Games: Mockingjay - Part 2
# 27       WB          160000000                                    Aquaman
# 39       WB          160000000                                  Inception
# 24       BV          150000000                                   Zootopia
# 11       WB          150000000                               Wonder Woman
# 16       BV          150000000                                     Frozen
# 8       LGF          130000000            The Hunger Games: Catching Fire
# 25      LGF          125000000      The Hunger Games: Mockingjay - Part 1
# 33      Fox          110000000                                 Deadpool 2
# 42       WB          110000000                                    Gravity
# 15     Sony           90000000             Jumanji: Welcome to the Jungle
# 14      LGF           80000000                           The Hunger Games
# 18     Uni.           76000000                            Despicable Me 2
# 43     Uni.           75000000                                       Sing
# 45     Uni.           75000000                            Despicable Me 3
# 17     Uni.           75000000                    The Secret Life of Pets
# 26     Uni.           74000000                                    Minions
# 38     Sum.           68000000                 The Twilight Saga: Eclipse
# 23       WB           58000000                            American Sniper
# 19      Fox           58000000                                   Deadpool
# 31  WB (NL)           35000000                                         It

# %%
# movie_studio = sns.load_dataset('movie_studio')
# sns.stripplot(x='studio', y='total_', data=df,
#               jitter=True, hue='smoker', dodge=True)

# %%
# graph_studio_df = movie_studio[['production_budget', 'studio']].groupby('studio').apply(lambda x: x.mean())
# graph_studio_df.sort_values('production_budget', inplace=True)
# graph_studio_df.reset_index(inplace=True)


# import matplotlib.patches as patches

# fig, ax = plt.subplots(figsize=(14,8), facecolor='white' ,dpi=80)
# ax.bar(x=graph_studio_df.index, y=graph_studio_df.production_budget, color='firebrick', alpha=0.7, linewidth=20)


# #for i, production_budget in enumerate(df.production_budget):
#     #ax.text(i, production_budget+0.5, round(production_budget, 1), horizontalalignment='center')



# ax.set_title('Studios and their limits', fontdict={'size':18})
# ax.set(ylabel='budgets', ylim=(0, 350))
# plt.xticks(graph_studio_df.index, graph_studio_df.studio.str.upper(), rotation=60, horizontalalignment='right', fontsize=12)


# # p1 = patches.Rectangle((.57, -0.005), width=.33, height=.13, alpha=.1, facecolor='green', transform=fig.transFigure)
# # p2 = patches.Rectangle((.124, -0.005), width=.446, height=.13, alpha=.1, facecolor='red', transform=fig.transFigure)

# %%
# mu, sigma = 100, 15
# x = mu + sigma * np.random.randn(10000)

# # the histogram of the data
# n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


# plt.xlabel('Smarts')
# plt.ylabel('Probability')
# plt.title('Histogram of IQ')
# plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
# plt.axis([40, 160, 0, 0.03])
# plt.grid(True)
# plt.show()

# %%
# # Draw Plot
# plt.figure(figsize=(14,8), dpi=80)
# sns.boxplot(x='studio', y='production_movie', data=movie_studio, hue='cyl')
# sns.stripplot(x='studio', y='production_movie', data=movie_studio, color='black', size=3, jitter=1)

# for i in range(len(movie_studio['studio'].unique())-1):
#     plt.vlines(i+.5, 10, 45, linestyles='solid', colors='gray', alpha=0.2)


# plt.title('Box Plot of Highway Mileage by Vehicle Class', fontsize=22)
# plt.legend(title='Studios')
# plt.show()
